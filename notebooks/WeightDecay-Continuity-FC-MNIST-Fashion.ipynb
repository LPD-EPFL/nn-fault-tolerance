# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
from experiment_train import *
from experiment_datasets import *
from helpers import *
import scipy.stats as st
import matplotlib
import pickle
import scipy
from scipy.optimize import curve_fit
from derivative_decay import *
# Out:
# Using TensorFlow backend.
# Initialized TensorFlow

# %%
# dimensions to try
Ns = [int(t) for t in np.linspace(50, 1500, 10)]

# how much repetitions for each experiment are needed?
repetitions = 1

print('Sizes', Ns)
print('Repetitions', repetitions)
print('Total runs', len(Ns) * repetitions)
# Out:
# Sizes [50, 211, 372, 533, 694, 855, 1016, 1177, 1338, 1500]
# Repetitions 1
# Total runs 10

# %%
# parameters for each experiment
parameters = {'reg_coeff': [1e-4, 1e-2], 'reg_type': 'continuous', 'do_print': 'plot', 'epochs': 30,
              'experiment': FashionMNISTExperiment}

# what to measure?
to_run = [show_neurons_1, dataset_metrics, show_W_profile, W_inf_norm, mean_dLdy, mean_d2Ldy2]

# %%
# obtaining an experiment
# scale
exp = experiment_for_N(100, parameters)

# %%
# does x have continuous limit?
# no, not really - it has ~28 discontinuities by construction
# need 2D?
plt.plot(exp.x_train[0])

# %%
# measuring...
results = get_results(Ns, repetitions, parameters, to_run)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# {'val_acc': 0.7926999986171722, 'train_acc': 0.8007833331823349, 'val_loss': 0.08441573157906532, 'train_loss': 0.08456318738559881}
# Layer 0
# IntDer, Conv {'derivative': 34.10861, 'smoothness': 0.7440446}
# Layer 1
# IntDer, Conv {'derivative': 164.93228, 'smoothness': 0.9102049}
# Layer 2
# IntDer, Conv {'derivative': 79.56149, 'smoothness': 0.0}
# True ans #0 9
#  10%|█         | 1/10 [00:20<03:02, 20.24s/it]
# {'val_acc': 0.8130999982357026, 'train_acc': 0.8270833283662796, 'val_loss': 0.07794936075806617, 'train_loss': 0.07690454460680485}
# Layer 0
# IntDer, Conv {'derivative': 56.275, 'smoothness': 0.20838124}
# Layer 1
# IntDer, Conv {'derivative': 131.03252, 'smoothness': 0.65927196}
# Layer 2
# IntDer, Conv {'derivative': 73.95456, 'smoothness': 0.0}
# True ans #0 9
#  20%|██        | 2/10 [00:43<02:48, 21.02s/it]
# {'val_acc': 0.8179999947547912, 'train_acc': 0.8265500028928121, 'val_loss': 0.08059580475091935, 'train_loss': 0.0799463264644146}
# Layer 0
# IntDer, Conv {'derivative': 69.079445, 'smoothness': 0.1860952}
# Layer 1
# IntDer, Conv {'derivative': 113.01601, 'smoothness': 0.56072605}
# Layer 2
# IntDer, Conv {'derivative': 76.00969, 'smoothness': 0.0}
# True ans #0 9
#  30%|███       | 3/10 [01:03<02:25, 20.85s/it]
# {'val_acc': 0.8185999929904938, 'train_acc': 0.8297333310047785, 'val_loss': 0.07468537539243698, 'train_loss': 0.07485004800061384}
# Layer 0
# IntDer, Conv {'derivative': 76.29231, 'smoothness': 0.19066045}
# Layer 1
# IntDer, Conv {'derivative': 86.67421, 'smoothness': 0.42051977}
# Layer 2
# IntDer, Conv {'derivative': 71.32244, 'smoothness': 0.0}
# True ans #0 9
#  40%|████      | 4/10 [01:27<02:11, 21.88s/it]
# {'val_acc': 0.8153000056743622, 'train_acc': 0.8259499996900559, 'val_loss': 0.0847623512148857, 'train_loss': 0.0842228215187788}
# Layer 0
# IntDer, Conv {'derivative': 89.89605, 'smoothness': 0.18027818}
# Layer 1
# IntDer, Conv {'derivative': 104.88455, 'smoothness': 0.5310571}
# Layer 2
# IntDer, Conv {'derivative': 70.05983, 'smoothness': 0.0}
# True ans #0 9
#  50%|█████     | 5/10 [01:51<01:51, 22.28s/it]
# {'val_acc': 0.8116999983787536, 'train_acc': 0.8220833331346512, 'val_loss': 0.08778410404920578, 'train_loss': 0.08910806042452653}
# Layer 0
# IntDer, Conv {'derivative': 97.08232, 'smoothness': 0.18796994}
# Layer 1
# IntDer, Conv {'derivative': 106.22703, 'smoothness': 0.5278681}
# Layer 2
# IntDer, Conv {'derivative': 68.59169, 'smoothness': 0.0}
# True ans #0 9
#  60%|██████    | 6/10 [02:16<01:33, 23.33s/it]
# {'val_acc': 0.8127000033855438, 'train_acc': 0.8262666662534078, 'val_loss': 0.08004570007324219, 'train_loss': 0.08005079614619413}
# Layer 0
# IntDer, Conv {'derivative': 106.539, 'smoothness': 0.14655301}
# Layer 1
# IntDer, Conv {'derivative': 84.050995, 'smoothness': 0.41858816}
# Layer 2
# IntDer, Conv {'derivative': 71.43274, 'smoothness': 0.0}
# True ans #0 9
#  70%|███████   | 7/10 [02:46<01:15, 25.26s/it]
# {'val_acc': 0.8202000021934509, 'train_acc': 0.8248666644096374, 'val_loss': 0.0835003562271595, 'train_loss': 0.08433551838000615}
# Layer 0
# IntDer, Conv {'derivative': 119.74356, 'smoothness': 0.16429572}
# Layer 1
# IntDer, Conv {'derivative': 87.65282, 'smoothness': 0.43932316}
# Layer 2
# IntDer, Conv {'derivative': 67.039085, 'smoothness': 0.0}
# True ans #0 9
#  80%|████████  | 8/10 [03:18<00:54, 27.27s/it]
# {'val_acc': 0.8178000032901764, 'train_acc': 0.8260666698217392, 'val_loss': 0.08106274008750916, 'train_loss': 0.08180301239093145}
# Layer 0
# IntDer, Conv {'derivative': 132.84421, 'smoothness': 0.16707925}
# Layer 1
# IntDer, Conv {'derivative': 71.23884, 'smoothness': 0.33934957}
# Layer 2
# IntDer, Conv {'derivative': 72.52102, 'smoothness': 0.0}
# True ans #0 9
#  90%|█████████ | 9/10 [03:55<00:30, 30.19s/it]
# {'val_acc': 0.8083999991416931, 'train_acc': 0.8229666670163472, 'val_loss': 0.09321527928113937, 'train_loss': 0.09251495413482189}
# Layer 0
# IntDer, Conv {'derivative': 144.3121, 'smoothness': 0.17405}
# Layer 1
# IntDer, Conv {'derivative': 86.73445, 'smoothness': 0.4160977}
# Layer 2
# IntDer, Conv {'derivative': 65.835754, 'smoothness': 0.0}
# True ans #0 9
# 100%|██████████| 10/10 [04:37<00:00, 27.72s/it]

# %%
pickle_w(results, "WeightDecay-Continuity-FC-MNIST-Fashion")

# %%
# filters at L1 look random when no regular/ization with continuity!

# %%
# loading results from a file
results = pickle_r("WeightDecay-Continuity-FC-MNIST-Fashion")

# %%
font = {'family' : 'normal',
        'weight' : 'normal',
        'size'   : 20}

matplotlib.rc('font', **font)

# %%
plot_results(Ns, results, name = 'WeightDecay-Continuity-FC-MNIST-Fashion')
# Out:
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# |W| seems to level out, D and H decay as they should (0.97 and 1.95)
