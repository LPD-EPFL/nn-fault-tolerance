# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
from matplotlib import pyplot as plt
import numpy as np
from keras import backend as K
from experiment_mnist import *
from tfshow import *
# Out:
# Using TensorFlow backend.

# %%
methods = ['l1', 'l2', 'delta', 'dropout', 'none']
activations = ['sigmoid', 'relu']
layers = [1,2,3,4,5,6]
reg_coeff = np.logspace(-3,3,10)

# %% [markdown]
# ### Relu, 2 layers, 10x10, 0.1 dropout, K = 1

# %%
experiment = MNISTExperiment([10, 10], 0.1, 1, epochs = 500, activation = 'relu', reg_type = 0,
                             reg_coeff = 0, do_print = True)
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_19 (Dense)             (None, 10)                7850
# _________________________________________________________________
# dense_20 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_21 (Dense)             (None, 10)                110
# ...
# Total params: 8,070
# Trainable params: 8,070
# Non-trainable params: 0
# _________________________________________________________________
# 100%|██████████| 500/500 [00:52<00:00,  9.62it/s]
# Creating network for 784-dimensional input and 10-dimensional output, with 2 hidden layers

# %%
experiment.get_accuracy(1000, 1000, tqdm_ = tqdm)
# Out:
# 100%|██████████| 1000/1000 [00:10<00:00, 97.27it/s]
# 0.607222
