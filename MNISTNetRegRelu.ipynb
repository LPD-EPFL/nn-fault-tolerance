# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
from matplotlib import pyplot as plt
import numpy as np
from keras import backend as K
from experiment_mnist import *
from helpers import *
from tfshow import *
# Out:
# Using TensorFlow backend.

# %%
experiment = MNISTExperiment([10, 10], 0.123, 0.321, epochs = 300, activation = 'relu', reg_type = 'delta',
                             reg_coeff = 0.01, do_print = True, update_C_inputs = 10000)
# Out:
#   0%|          | 0/300 [00:00<?, ?it/s]
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_67 (Dense)             (None, 10)                7850
# _________________________________________________________________
# dense_68 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_69 (Dense)             (None, 10)                110
# =================================================================
# Total params: 8,070
# Trainable params: 8,070
# Non-trainable params: 0
# _________________________________________________________________
# 100%|██████████| 300/300 [00:36<00:00,  8.34it/s]
# Creating network for 784-dimensional input and 10-dimensional output, with 2 hidden layers

# %%
experiment.run(repetitions = 10000, inputs = 100)
# Out:
# 100%|██████████| 100/100 [00:12<00:00,  8.42it/s]
# Error; maximal over inputs, average over dropout:
# True values array mean: 0.097235 variance 0.201805
# Experiment 0.298489 Std 0.506522
# Equation   0.670237 Std 1.764994
# Tightness  44.5% Std 28.7%
# (0.2984893, 0.5065221, 0.6702368762177227, 1.7649940232745347, 0.2018045)
