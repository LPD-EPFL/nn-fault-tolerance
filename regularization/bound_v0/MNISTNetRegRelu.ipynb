# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
from matplotlib import pyplot as plt
import numpy as np
from keras import backend as K
from experiment_mnist import *
from helpers import *
from tfshow import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
experiment = MNISTExperiment([10, 10], 0.123, 0.321, epochs = 1000, activation = 'relu', reg_type = 'delta',
                             reg_coeff = 0.01, do_print = True, update_C_inputs = 10000)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_76 (Dense)             (None, 10)                7850
# _________________________________________________________________
# dense_77 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_78 (Dense)             (None, 10)                110
# ...
# Total params: 8,070
# Trainable params: 8,070
# Non-trainable params: 0
# _________________________________________________________________
# 100%|██████████| 1000/1000 [02:00<00:00,  8.20it/s]
# Creating network for 784-dimensional input and 10-dimensional output, with 2 hidden layers

# %%
experiment.run(repetitions = 10000, inputs = 10000)
# Out:
# 100%|██████████| 10000/10000 [22:12<00:00,  8.27it/s]
# Error; maximal over inputs, average over dropout:
# True values array mean: 0.097117 variance 0.224047
# Experiment 0.386735 Std 0.698558
# Equation   0.935369 Std 2.359725
# Tightness  41.3% Std 29.6%
# (0.38673532, 0.69855803, 0.9353690163178893, 2.359725372645953, 0.22404747)
